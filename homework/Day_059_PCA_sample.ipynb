# %% [markdown]
# # PCA 範例

# %% [markdown]
# (Optional) 若尚未安裝相關套件，執行下一行，然後 restart kernel

# %%
# !pip3 install --user sklearn
# !pip3 install --user --upgrade matplotlib

# %% [markdown]
# 載入套件

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


from sklearn import decomposition
from sklearn import datasets

np.random.seed(5)
# %matplotlib inline

# %% [markdown]
# 載入 iris 資料集

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# 設定 模型 估計參數

# %%
centers = [[1, 1], [-1, -1], [1, -1]]
pca = decomposition.PCA(n_components=3)

# %% [markdown]
# 資料建模 並 視覺化 結果

# %%
fig = plt.figure(1, figsize=(8, 6))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=30, azim=75)
plt.cla()


for name, label in [('Setosa', 0), ('Versicolour', 1), ('Virginica', 2)]:
    ax.text3D(X[y == label, 0].mean(),
              X[y == label, 1].mean() + 1.5,
              X[y == label, 2].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))
# Reorder the labels to have colors matching the cluster results
y_tmp = np.choose(y, [1, 2, 0]).astype(np.float)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y_tmp, cmap=plt.cm.nipy_spectral,
           edgecolor='k')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])

plt.show()

# %%
pca.fit(X)
X = pca.transform(X)

fig = plt.figure(1, figsize=(8, 6))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=30, azim=75)
plt.cla()


for name, label in [('Setosa', 0), ('Versicolour', 1), ('Virginica', 2)]:
    ax.text3D(X[y == label, 0].mean(),
              X[y == label, 1].mean() + 1.5,
              X[y == label, 2].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))
# Reorder the labels to have colors matching the cluster results
y_tmp = np.choose(y, [1, 2, 0]).astype(np.float)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.nipy_spectral,
           edgecolor='k')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])

plt.show()

# %% [markdown]
# #### 參考資料
#
# 1. Unsupervised learning 影片來源：Statistical Learning
# [![](https://img.youtube.com/vi/ipyxSYXgzjQ/0.jpg)](https://youtu.be/ipyxSYXgzjQ)
# 2. Further Principal Components 影片來源：Statistical Learning
# [![](https://img.youtube.com/vi/dbuSGWCgdzw/0.jpg)](https://youtu.be/dbuSGWCgdzw)
# 3. Principal Components Regression 影片來源：Statistical Learning
# [![](https://img.youtube.com/vi/eYxwWGJcOfw/0.jpg)](https://youtu.be/eYxwWGJcOfw)
# 4. Dimentional Reduction 影片來源 Andrew Ng
# [![](https://img.youtube.com/vi/rng04VJxUt4/0.jpg)](https://youtu.be/rng04VJxUt4)
